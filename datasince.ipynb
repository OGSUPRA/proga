# %% [markdown]
# <a href="https://colab.research.google.com/github/OGSUPRA/proga/blob/master/datasince.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

df = pd.read_csv('/content/drive/MyDrive/data_set/data1.csv')
df
# Out:
#        Unnamed: 0  test_values  Unnamed: 2  for_notes         hotel  \
# 0               0          NaN         NaN        NaN  Resort Hotel
# 1               1          NaN         NaN        NaN    For notes:
# 2               2          NaN         NaN        NaN  Resort Hotel
# 3               3          NaN         NaN        NaN    For notes:
# 4               4          NaN         NaN        NaN  Resort Hotel
# ...           ...          ...         ...        ...           ...
# 23873       23873          NaN         NaN        NaN    For notes:
# 23874       23874          NaN         NaN        NaN  Resort Hotel
# 23875       23875          NaN         NaN        NaN    For notes:
# 23876       23876          NaN         NaN        NaN  Resort Hotel
# 23877       23877          NaN         NaN        NaN    For notes:
#
#        is_canceled  lead_time  arrival_date_year arrival_date_month  cashe  \
# ...
