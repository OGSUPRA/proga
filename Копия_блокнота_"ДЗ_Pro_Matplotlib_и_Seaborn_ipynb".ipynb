# %% [markdown]
# <a href="https://colab.research.google.com/github/OGSUPRA/proga/blob/master/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%94%D0%97_Pro_Matplotlib_%D0%B8_Seaborn_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание по Matplotlib и Seaborn
# # Pro
#
# ### *Часть 1. Matplotlib*

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### **Задача 1**
#
# *2 балла*
#
# Используя библиотеку Matplotlib, для датасета "Ирисы", который подгружается кодом ниже, нарисуйте точечную диаграмму (scatter plot) всех четырех признаков. Каждый признак должен быть нарисован на отдельном графике. Используйте для этого subplot формата 2 на 2. Графики должны быть читаемыми, т. е. отрегулируйте размер subplot'ов. Добавьте названия признаков к каждому графику в качестве имени графика (названия признаков можно получить с помощью метода .feature_names). Используйте метки классов (y) в качестве цветовой разметки. Добавьте расшифровку цветов, соответствующих меткам классов, в качестве лейблов.
#
# P.S. Используйте функцию plt.scatter(x, y, color).

# %%
from sklearn import datasets
data = datasets.load_iris(return_X_y=False)
x = data.data
y = data.target
names = data.target_names

# %%
data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
print(y.max())
print(y.min())
# Out:
# 2
# 0

# %%
plt.plot(x)
plt.show()

# %%
df = pd.DataFrame(x)
df
# df.Columns().sum()
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ### **Решение:**

# %%
plt.figure(figsize=(10,10))

names_par = data.feature_names
for i in range(4):
  plt.subplot(2,2,i+1)
  plt.scatter(range(50), X[:50, i], label=names[0], c='r')
  plt.scatter(range(50,100), X[50:100, i], label=names[1], c='b')
  plt.scatter(range(100,150), X[100:150, i], label=names[2], c='g')
  plt.title(data.feature_names[i])
  plt.xlabel('range')
  plt.ylabel(data.feature_names[i])
  plt.legend()
plt.show()

# %% [markdown]
# ### **Задача 2**
#
# *2 балла*
#
# Используя библиотеку Matplotlib, постройте гистограмму для первого признака в датасете выше следующим образом:
# * на одном графике должно быть три гистограммы, по одной на каждый класс,
# * для этого используйте методологии подвыборки массива с условием,
# * количество бинов должно определяться автоматически (режим "auto"),
# * гистограмма должна быть читаемой, т. е. добавьте подписи, лейблы, названия и т. д.

# %% [markdown]
# ### **Решение:**

# %%
plt.hist(x[:50,0])
plt.hist(x[50:100,0], alpha=0.7)
plt.hist(x[100:,0], alpha=0.7)
plt.title('Гистограмма первого признака')
plt.xlabel(data.feature_names[0])
plt.ylabel('количество экземпляров')
plt.legend(names)
plt.show()

# %%
plt.hist(x[:50,1])
plt.hist(x[50:100,1], alpha = 0.7)
plt.hist(x[100:150,1], alpha = 0.5)
plt.title("Гистограмма второго признака")
plt.xlabel(data.feature_names[1])
plt.ylabel("Количество экземпляров")
plt.legend(names)
plt.show()

# %%
plt.hist(x[:50,2])
plt.hist(x[50:100,2])
plt.hist(x[100:150,2], alpha = 0.7)
plt.title("Гистограмма 3 признака")
plt.xlabel(data.feature_names[2])
plt.ylabel('Количество экземпляров')
plt.legend(names)
plt.show()

# %%
plt.hist(x[:50, 3])
plt.hist(x[50:100, 3],alpha = 0.7)
plt.hist(x[100:150, 3], alpha = 0.7)
plt.title("Гистограмма 4 признака")
plt.xlabel(data.feature_names[3])
plt.ylabel("Количество экземпляров")
plt.legend(names)
plt.show()

# %% [markdown]
# ### **Задача 3**
#
# *2 балла*
#
# Используя библиотеку Matplotlib, посчитайте матрицу корреляции между признаками и нарисуйте ее как heatmap. Подберите подходящую по смыслу цветовую гамму. Добавьте названия признаков в качестве тиков по осям. Добавьте отрисовку цветовой шкалы.

# %% [markdown]
# ### **Решение:**

# %%
df = pd.DataFrame(x,y)
print(df.head())
print(names)
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 0  4.9  3.0  1.4  0.2
# 0  4.7  3.2  1.3  0.2
# 0  4.6  3.1  1.5  0.2
# 0  5.0  3.6  1.4  0.2
# ['setosa' 'versicolor' 'virginica']

# %%
to_plot= df.corr()
to_plot
# Out:
#           0         1         2         3
# 0  1.000000 -0.117570  0.871754  0.817941
# 1 -0.117570  1.000000 -0.428440 -0.366126
# 2  0.871754 -0.428440  1.000000  0.962865
# 3  0.817941 -0.366126  0.962865  1.000000

# %%
to_plot= df.corr()
plt.imshow(to_plot, cmap="Blues")
plt.colorbar()
plt.xticks(range(4),data.feature_names, rotation=45, color='black')
plt.show()

# %% [markdown]
# ### *Часть 2. Seaborn*

# %% [markdown]
# ### **Задача 4**
#
# *2 балла*
#
# Для датасета Occupancy (datatraining.txt) постройте диаграмму присутствия в разбивке по часам и меткам классов *(метки классов хранятся в столбце 'occupancy)'*. Для этого сделайте следующее:
# *   создайте новый столбец "hour", отвечающий соответствующему часу,
# *   нарисуйте sns.countplot этого столбца в разбивке по Occupancy.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ### **Решение:**

# %%
df = pd.read_csv("/content/drive/MyDrive/datatraining.txt")
df
# Out:
#                      date  Temperature  Humidity  Light         CO2  \
# 1     2015-02-04 17:51:00        23.18   27.2720  426.0  721.250000
# 2     2015-02-04 17:51:59        23.15   27.2675  429.5  714.000000
# 3     2015-02-04 17:53:00        23.15   27.2450  426.0  713.500000
# 4     2015-02-04 17:54:00        23.15   27.2000  426.0  708.250000
# 5     2015-02-04 17:55:00        23.10   27.2000  426.0  704.500000
# ...                   ...          ...       ...    ...         ...
# 8139  2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000
# 8140  2015-02-10 09:29:59        21.05   35.9950  433.0  789.500000
# 8141  2015-02-10 09:30:59        21.10   36.0950  433.0  798.500000
# 8142  2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333
# 8143  2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000
#
#       HumidityRatio  Occupancy
# 1          0.004793          1
# 2          0.004783          1
# 3          0.004779          1
# 4          0.004772          1
# 5          0.004757          1
# ...             ...        ...
# 8139       0.005579          1
# 8140       0.005563          1
# 8141       0.005596          1
# 8142       0.005621          1
# 8143       0.005612          1
#
# [8143 rows x 7 columns]

# %%
df.index = pd.to_datetime(df['date'])
df.drop('date', axis=1, inplace=True)
df
# Out:
#                      Temperature  Humidity  Light         CO2  HumidityRatio  \
# date
# 2015-02-04 17:51:00        23.18   27.2720  426.0  721.250000       0.004793
# 2015-02-04 17:51:59        23.15   27.2675  429.5  714.000000       0.004783
# 2015-02-04 17:53:00        23.15   27.2450  426.0  713.500000       0.004779
# 2015-02-04 17:54:00        23.15   27.2000  426.0  708.250000       0.004772
# 2015-02-04 17:55:00        23.10   27.2000  426.0  704.500000       0.004757
# ...                          ...       ...    ...         ...            ...
# 2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000       0.005579
# 2015-02-10 09:29:59        21.05   35.9950  433.0  789.500000       0.005563
# 2015-02-10 09:30:59        21.10   36.0950  433.0  798.500000       0.005596
# 2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333       0.005621
# 2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000       0.005612
#
#                      Occupancy
# date
# 2015-02-04 17:51:00          1
# 2015-02-04 17:51:59          1
# 2015-02-04 17:53:00          1
# 2015-02-04 17:54:00          1
# 2015-02-04 17:55:00          1
# ...                        ...
# 2015-02-10 09:29:00          1
# 2015-02-10 09:29:59          1
# 2015-02-10 09:30:59          1
# 2015-02-10 09:32:00          1
# 2015-02-10 09:33:00          1
#
# [8143 rows x 6 columns]

# %%
df['hour'] = df.index.hour
df
# Out:
#                      Temperature  Humidity  Light         CO2  HumidityRatio  \
# date
# 2015-02-04 17:51:00        23.18   27.2720  426.0  721.250000       0.004793
# 2015-02-04 17:51:59        23.15   27.2675  429.5  714.000000       0.004783
# 2015-02-04 17:53:00        23.15   27.2450  426.0  713.500000       0.004779
# 2015-02-04 17:54:00        23.15   27.2000  426.0  708.250000       0.004772
# 2015-02-04 17:55:00        23.10   27.2000  426.0  704.500000       0.004757
# ...                          ...       ...    ...         ...            ...
# 2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000       0.005579
# 2015-02-10 09:29:59        21.05   35.9950  433.0  789.500000       0.005563
# 2015-02-10 09:30:59        21.10   36.0950  433.0  798.500000       0.005596
# 2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333       0.005621
# 2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000       0.005612
#
#                      Occupancy  hour
# date
# 2015-02-04 17:51:00          1    17
# 2015-02-04 17:51:59          1    17
# 2015-02-04 17:53:00          1    17
# 2015-02-04 17:54:00          1    17
# 2015-02-04 17:55:00          1    17
# ...                        ...   ...
# 2015-02-10 09:29:00          1     9
# 2015-02-10 09:29:59          1     9
# 2015-02-10 09:30:59          1     9
# 2015-02-10 09:32:00          1     9
# 2015-02-10 09:33:00          1     9
#
# [8143 rows x 7 columns]

# %%
df['hour'] = pd.DatetimeIndex(df.index).hour
sns.countplot(data=df, x=df.hour, hue='Occupancy')
plt.show()

# %% [markdown]
# ### **Задача 5**
#
# *2 балла*
#
# Сделайте resample данных по получасовому интервалу с использованием усреднения для всех признаков.
#
# Постройте sns.jointplot между признаками Light и CO2.

# %% [markdown]
# ### **Решение:**

# %%
data_new = df.resample('30min').mean()
sns.jointplot(x=data_new.Light,y=data_new.CO2, data = data_new)
plt.show()
