# %% [markdown]
# <a href="https://colab.research.google.com/github/OGSUPRA/proga/blob/master/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%94%D0%97_Pro_%D0%A4%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8_%D0%B8_%D0%BC%D0%BE%D0%B4%D1%83%D0%BB%D0%B8_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание
# Функции и модули
# # Pro

# %% [markdown]
# **Задача 1**
#
# Напишите функцию, которая принимает на вход строку и считает количество букв в  верхнем и нижнем регистрах.
# Пример: 'На берегу Амазонки сидел Фернандо'.
# Что должно быть на выходе?
#
# Количество букв в верхнем регистре: 3
#
# Количество букв в нижнем регистре: 26

# %% [markdown]
# **Решение:**

# %%
def uplow():
  user_wrd = str(input())
  up_cound = 0
  low_cound = 0
  for i in user_wrd:
    if i.isupper():
      up_cound += 1
    elif i.islower():
      low_cound += 1
  print('Количество букв в верхнем регистре:',up_cound)
  print('Количество букв в нижнем регистре:',low_cound)
uplow()
# Out:
# На берегу Амазонки сидел Фернандо
# Количество букв в верхнем регистре: 3
# Количество букв в нижнем регистре: 26

# %% [markdown]
# **Задача 2**
#
# Напишите функцию, которая принимает на вход число и проверяет, если оно простое.
#
# Простые числа - это натуральные(целые положительные) числа, которые делятся только на себя или на единицу.
# Пример: 3 - это простое число, т. к. нацело 3 делится только на 3 и на 1.

# %% [markdown]
# **Решение:**

# %%
def simple_number(num):
  user_number = num
  a = 0
  for i in range(2, user_number // 2 + 1):
    if user_number % i == 0:
      a += 1
  if (user_number % 1 == 0) and (user_number % user_number == 0) and (a == 0) and (user_number != 1):
    print("число простое")
  else:
    print("число не простое")

for i in range(1,101):
  print(i)
  simple_number(i)
# Out:
# 1
# число не простое
# 2
# число простое
# 3
# число простое
# 4
# число не простое
# 5
# число простое
# 6
# число не простое
# 7
# число простое
# 8
# число не простое
# 9
# число не простое
# 10
# число не простое
# 11
# число простое
# 12
# число не простое
# 13
# число простое
# 14
# число не простое
# 15
# число не простое
# 16
# число не простое
# 17
# число простое
# 18
# число не простое
# 19
# число простое
# 20
# число не простое
# 21
# число не простое
# 22
# число не простое
# 23
# число простое
# 24
# число не простое
# 25
# число не простое
# 26
# число не простое
# 27
# число не простое
# 28
# число не простое
# 29
# число простое
# 30
# число не простое
# 31
# число простое
# 32
# число не простое
# 33
# число не простое
# 34
# число не простое
# 35
# число не простое
# 36
# число не простое
# 37
# число простое
# 38
# число не простое
# 39
# число не простое
# 40
# число не простое
# 41
# число простое
# 42
# число не простое
# 43
# число простое
# 44
# число не простое
# 45
# число не простое
# 46
# число не простое
# 47
# число простое
# 48
# число не простое
# 49
# число не простое
# 50
# число не простое
# 51
# число не простое
# 52
# число не простое
# 53
# число простое
# 54
# число не простое
# 55
# число не простое
# 56
# число не простое
# 57
# число не простое
# 58
# число не простое
# 59
# число простое
# 60
# число не простое
# 61
# число простое
# 62
# число не простое
# 63
# число не простое
# 64
# число не простое
# 65
# число не простое
# 66
# число не простое
# 67
# число простое
# 68
# число не простое
# 69
# число не простое
# 70
# число не простое
# 71
# число простое
# 72
# число не простое
# 73
# число простое
# 74
# число не простое
# 75
# число не простое
# 76
# число не простое
# 77
# число не простое
# 78
# число не простое
# 79
# число простое
# 80
# число не простое
# 81
# число не простое
# 82
# число не простое
# 83
# число простое
# 84
# число не простое
# 85
# число не простое
# 86
# число не простое
# 87
# число не простое
# 88
# число не простое
# 89
# число простое
# 90
# число не простое
# 91
# число не простое
# 92
# число не простое
# 93
# число не простое
# 94
# число не простое
# 95
# число не простое
# 96
# число не простое
# 97
# число простое
# 98
# число не простое
# 99
# число не простое
# 100
# число не простое

# %% [markdown]
# **Задача 3**
#
# Напишите функцию, которая проверяет, если число совершенное.
# Совершенным числом является положительное число, такое, что оно является суммой собственных положительных делителей (все, кроме самого числа).
# Пример: первым в числовом ряду совершенным числом является 6: 1+2+3=6
# Найдите такие числа в промежутке, который вы будете вводить с клавиатуры (два числа: начало и конец промежутка), например, промежуток от 5 до 150.

# %% [markdown]
# **Решение:**

# %%
def perfect(num):

  del2 = num//2
  del_list = []
  for i in range(1,del2+1):
    if num % i == 0:
      del_list += [i]
  sum_num = sum(del_list)
  del_list += [num]
  if sum_num == num:
    print(num," число совершенное")

x = int(input('начало промежутка '))
y = int(input('конец промежутка '))
for i in range (x, y+1):
  perfect(i)
# Out:
# начало промежутка 5
# конец промежутка 8500
# 6  число совершенное
# 28  число совершенное
# 496  число совершенное
# 8128  число совершенное

# %% [markdown]
# **Задача 4**
#
# Напишите функцию, которая проверяет, если фраза является палиндромом. Пример такой фразы:
#
# а роза упала на лапу Азора.

# %% [markdown]
# **Решение:**

# %%
user_wrd1 = input()
user_wrd2 = input()
def polid(wrd):
  wrd1 = wrd.replace(',', '').replace(' ', '').replace('.','').lower()
  res_wrd = wrd1[::-1]
  if wrd1 == res_wrd:
    print(wrd,": Является палиндромом")
  else:
    print(wrd,": Не является палиндромом")
polid(user_wrd1)
polid(user_wrd2)
# Out:
# а роза упала на лапу Азора.
# ПРИВЕТ МИР
# а роза упала на лапу Азора. : Является палиндромом
# ПРИВЕТ МИР : Не является палиндромом

# %% [markdown]
# **Задача 5**
#
# Посчитать значение $\cos^2(\pi/7)$ и $\sin^2(\pi/7)$, используя указанные функции из библиотеки ```math```, применив для этого **каждую** из конструкций импорта:
# ```
# # 1. Импорт модуля или модулей целиком
# import имя_модуля
#
# # 2. Импорт модуля с присвоением псевдонима модулю
# import имя_модуля as новое_имя
#
# # 3. Импорт конкретного объекта из модуля
# from имя_модуля import имя_объекта
# from имя_модуля import имя_объекта1, имя_объекта2
#
# # 4. Импорт конкретного объекта из модуля с присвоением псевдонима объекту
# from имя_модуля import имя_объекта as псевдоним_объекта
#
# # 5. Импорт всех объектов из модуля
# from имя_модуля import *
# ```
# Найдите сумму $\cos^2(\pi/7)$ и $\sin^2(\pi/7)$.

# %% [markdown]
# **Решение:**

# %%
from math import pi,cos,sin

sam = (cos(pi/7))**2 + (sin(pi/7))**2
print(sam)
# Out:
# 1.0
